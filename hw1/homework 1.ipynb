# %%
import numpy as np

# %% [markdown]
# ### task 1

# %%
a = np.array([1, 2, 3, 3, 1, 6, 8, 11, 10, 7]).reshape((2,5))
a
# Out:
# array([[ 1,  2,  3,  3,  1],
#        [ 6,  8, 11, 10,  7]])

# %%
mean_a = a.mean(axis=0)
mean_a
# Out:
# array([3.5, 5. , 7. , 6.5, 4. ])

# %% [markdown]
# ### task 2
